# %% [markdown]
# ## **Saifali Sayed**

# %% [markdown]
# # **Data Science & Business Analytics Intern @ The Spark Foundation (TSF)**
#
# **Task-4**: Exploratory Data Analysis Sports(Advanced Level)
#
# **Batch**:may23

# %% [markdown]
# **To Explore Buisness Analytics Objective:**
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’
#
# ● As a sports analysts, find out the most successful teams, players and factors contributing win or loss of a team.
#
# ● Suggest teams or players a company should endorse for its products.
#
# **What is Exploratory Data Analysis?**
#
# Exploratory Data Analysis (EDA) is an approach that is used to analyze the data and discover trends, patterns, or check assumptions in data with the help of statistical summaries and graphical representations.

# %% [markdown]
# ***Import Libraries***

# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Loading the Datasets**

# %%
matches = pd.read_csv('/content/matches.csv')
delivery = pd.read_csv('/content/deliveries.csv')

# %%
print(f'Number of rows    = {len(matches)}')
print(f'Number of columns = {len(matches.columns)}')
# Out:
# Number of rows    = 756
# Number of columns = 18

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
print(f'Number of rows    = {len(delivery)}')
print(f'Number of columns = {len(delivery.columns)}')
# Out:
# Number of rows    = 179078
# Number of columns = 21

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
print(matches.describe())
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
print(delivery.describe())
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# **Cleaning the Data**

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
delivery.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# **Dropping the Column**

# %%
matches.drop(columns=['umpire1','umpire2'], inplace=True)

# %%
matches.shape
# Out:
# (756, 16)

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire3'],
#       dtype='object')

# %%
matches.team1.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
matches.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %% [markdown]
# **Print random five**

# %%
matches.sample(5)
# Out:
#       id  season        city        date                        team1  \
# 339  340    2012  Chandigarh  2012-04-25              Kings XI Punjab
# 569  570    2015      Mumbai  2015-05-16             Rajasthan Royals
# 206  207    2010      Mumbai  2010-04-03               Mumbai Indians
# 601  602    2016       Delhi  2016-04-30             Delhi Daredevils
# 494  495    2014   Bangalore  2014-05-13  Royal Challengers Bangalore
#
#                      team2            toss_winner toss_decision  result  \
# 339         Mumbai Indians        Kings XI Punjab           bat  normal
# 569  Kolkata Knight Riders       Rajasthan Royals           bat  normal
# 206        Deccan Chargers         Mumbai Indians           bat  normal
# 601  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 494       Delhi Daredevils       Delhi Daredevils         field  normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# Making Mumbai as Bombay

# %%
matches.city.replace({'Mumbai' : 'Bombay'},inplace=True)
matches.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Bombay',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
matches.id.count()
# Out:
# 756

# %% [markdown]
# **Finding the number of teams who played IPL till 2018**

# %%
print(matches.team1.unique())
print('{} different teams played the IPL from 2008-2018'.format(matches.team1.unique().shape[0]))
# Out:
# ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bangalore'
#  'Kolkata Knight Riders' 'Delhi Daredevils' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Rajasthan Royals' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Rising Pune Supergiants'
#  'Delhi Capitals']
# 15 different teams played the IPL from 2008-2018

# %% [markdown]
# **NUMBER OF MATCHES IN EACH SEASON**

# %%
num_matches_matches = matches.groupby('season')[['id']].count()
num_matches_matches
# Out:
#         id
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60

# %% [markdown]
# **Number of matches in each season**

# %%
plt.title('Number of matches in each season',fontweight=800)
plt.xlabel('Seasons')
plt.ylabel('Total no. of matches')
plt.xticks(num_matches_matches.index)
plt.bar(num_matches_matches.index,num_matches_matches.id,width=0.8, color=['red','yellow','blue','green','purple','grey',
               'orange','pink','violet','brown',
               'black','cyan'], alpha=0.8);

# %% [markdown]
# **Number of matches won by each team from 2008-2018**

# %%
winner_matches = matches.groupby('winner')[['id']].count()
winner_matches=winner_matches.sort_values('id', ascending=False).reset_index()

winner_matches.rename(columns = { 'id': 'matches_won','winner':'team'}, inplace = True)
winner_matches
# Out:
#                            team  matches_won
# 0                Mumbai Indians          109
# 1           Chennai Super Kings          100
# 2         Kolkata Knight Riders           92
# 3   Royal Challengers Bangalore           84
# 4               Kings XI Punjab           82
# 5              Rajasthan Royals           75
# 6              Delhi Daredevils           67
# 7           Sunrisers Hyderabad           58
# 8               Deccan Chargers           29
# 9                 Gujarat Lions           13
# 10                Pune Warriors           12
# 11               Delhi Capitals           10
# 12       Rising Pune Supergiant           10
# 13         Kochi Tuskers Kerala            6
# 14      Rising Pune Supergiants            5

# %% [markdown]
# **Number of matches in each season**

# %%
plt.title('Number of matches won by each team from 2008-2018',fontweight=800)
plt.xlabel('Teams')
plt.ylabel('Total no. of matches won')
plt.xticks(rotation=90,fontsize=10)
plt.bar(winner_matches.team,winner_matches.matches_won, color=['red','yellow','blue','green','purple','grey',
               'orange','pink','violet','brown','#158EA6','#E82865',
               '#005DB7','#C23E25','#E82878'], alpha=0.8)
# Out:
# <BarContainer object of 15 artists>

# %%
final_match_matches = matches.groupby('season').tail(1).sort_values('season').reset_index()
final_match_matches
# Out:
#     index     id  season          city        date                team1  \
# 0     116    117    2008        Bombay  2008-06-01  Chennai Super Kings
# 1     173    174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 2     233    234    2010        Bombay  2010-04-25  Chennai Super Kings
# 3     306    307    2011       Chennai  2011-05-28  Chennai Super Kings
# 4     380    381    2012       Chennai  2012-05-27  Chennai Super Kings
# 5     456    457    2013       Kolkata  2013-05-26       Mumbai Indians
# 6     516    517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 7     575    576    2015       Kolkata  2015-05-24       Mumbai Indians
# 8     635    636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
# 9      58     59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 10    695   7953    2018        Bombay    27/05/18  Sunrisers Hyderabad
# 11    755  11415    2019     Hyderabad    12/05/19       Mumbai Indians
#
# ...

# %%
plt.title('Count of Season Winners',fontweight=800)
sns.countplot(x=final_match_matches['winner'],palette=['red','yellow','blue','green','purple','grey',]);

# %%
final_match_matches['winner'].value_counts()
# Out:
# Mumbai Indians           4
# Chennai Super Kings      3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Name: winner, dtype: int64

# %%
plt.title('Count of Finalists in IPL',fontweight=800)
plt.xlabel('Teams')
sns.countplot(x=final_match_team,palette=['#FFFF48','#1C2C46','#15244C','#CD202D','#D4480B','#ECC5F2','#EF2920','#F0E1A1','#E776CA'])
plt.ylabel('Final Matches Played')
plt.xticks(rotation=90);

# %%
final_match_team = pd.concat([final_match_matches['team1'],final_match_matches['team2']])
final_match_team.value_counts()
# Out:
# Chennai Super Kings            8
# Mumbai Indians                 5
# Royal Challengers Bangalore    3
# Sunrisers Hyderabad            2
# Kolkata Knight Riders          2
# Deccan Chargers                1
# Kings XI Punjab                1
# Rajasthan Royals               1
# Rising Pune Supergiant         1
# dtype: int64

# %%
mom_count =matches.groupby('player_of_match')[['id']].count()
mom_count = mom_count.sort_values('id',ascending=False).head(10)
mom_count
# Out:
#                  id
# player_of_match
# CH Gayle         21
# AB de Villiers   20
# MS Dhoni         17
# DA Warner        17
# RG Sharma        17
# YK Pathan        16
# SR Watson        15
# SK Raina         14
# G Gambhir        13
# MEK Hussey       12

# %%
plt.title("Top 10 Player with Most Man of the Match Awards",fontweight=800 )
sns.barplot(x=mom_count.index,y=mom_count.id, alpha=0.6);
plt.xticks(rotation=90)
plt.yticks(ticks=np.arange(0,25,5))
plt.ylabel('No. of Awards')
plt.xlabel('Players');

# %%
plt.title("Top 10 Player with Most Man of the Match Awards",fontweight=800 )
sns.barplot(x=mom_count.index,y=mom_count.id, alpha=0.6);
plt.xticks(rotation=90)
plt.yticks(ticks=np.arange(0,25,5))
plt.ylabel('No. of Awards')
plt.xlabel('Players');

# %%
city_counts= matches.groupby('city').apply(lambda x:x['city'].count()).reset_index(name='Match Counts')
top_cities_order=city_counts.sort_values(by='Match Counts',ascending=False)
top_cities=top_cities_order[:10]
print('Top 10 Cities with the maximum number of Matches Played:\n',top_cities)
plt.figure(figsize=(7,7))
plt.pie(top_cities['Match Counts'],labels=top_cities['city'],autopct='%1.1f%%', startangle=30)
plt.axis('equal')
plt.title('Top Cities that have hosted IPL Matches',size=10)
# Out:
# Top 10 Cities with the maximum number of Matches Played:
#            city  Match Counts
# 5       Bombay           101
# 22     Kolkata            77
# 11       Delhi            74
# 2    Bangalore            66
# 15   Hyderabad            64
# 9      Chennai            57
# 17      Jaipur            47
# 8   Chandigarh            46
# 26        Pune            38
# 13      Durban            15
# Text(0.5, 1.0, 'Top Cities that have hosted IPL Matches')

# %%
sns.pairplot(delivery)

# %% [markdown]
# # **Conclusion**
#
# As a Sports Analyst, Mumbai Indians is the most successful team in the IPL,having won the mst tosses. Chasing the total(419)matches won more matches than defending(350)matches.
#
# The largest victory when defending a total was by 146 runs(Mumbai Indians defented Delhi Daredavils by 146 runs on 6 May 2017 at Feroz Shah Kotla Stadium in Delhi).The City of Mumbai has hosted the most IPL matches.Chris Gayle has earned the most player of the match titles. Thankyou:)
